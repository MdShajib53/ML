# %% [markdown]
# <h1 style='color:Green'>Introduction</h1>

# %% [markdown]
# [View the PDF](./001-Introduction.pdf)

# %%
from IPython.display import IFrame
IFrame("001-Introduction.pdf", width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="001-Introduction.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
